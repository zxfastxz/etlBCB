# %% [markdown]
# Gerando conexão com banco de dados db em um jupyter e depois analisar os dados com pandas

# %%
import pandas as pd
import sqlite3

# %%
con = sqlite3.connect("src/datasets/dadosbcb.db")
query = "select * from meiosPagamentosTri"
df = pd.read_sql(query, con)
con.close()

# %%
df
# Out:
#           datatrimestre    valorPix     valorTED  valorTEC  valorCheque  \
# 0   2024-12-31 00:00:00  7714115.37  11647265.67      0.00    187486.45
# 1   2024-09-30 00:00:00  6975429.47  11180217.68      0.00    194330.60
# 2   2024-06-30 00:00:00  6284296.05  10662555.73      0.00    221553.82
# 3   2024-03-31 00:00:00  5429305.43   9651625.56    925.26    190457.25
# 4   2023-12-31 00:00:00  5300155.00  10090921.81   5787.89    221424.78
# 5   2023-09-30 00:00:00  4469529.57   9960251.89   4156.38    218121.88
# 6   2023-06-30 00:00:00  3900377.43  10657463.13   4770.74    228408.82
# 7   2023-03-31 00:00:00  3447198.28   9919602.84   4535.17    240686.19
# 8   2022-12-31 00:00:00  3342913.94  10382121.63   5609.53    242259.61
# 9   2022-09-30 00:00:00  2936413.95  10437763.16   3735.46    267090.22
# 10  2022-06-30 00:00:00  2543384.40  10449574.67   4786.14    271008.09
# 11  2022-03-31 00:00:00  2067826.55   9507158.34   3865.81    255455.43
# ...

# %%
soma = df['valorPix'].sum() * 1e6
soma
# Out:
# np.float64(59764956970000.0)

# %%
total = df['valorPix'].count()
total
# Out:
# np.int64(24)

# %%
print("Média das transações pix por trimestre: ", round(soma / total, 2))
# Out:
# Média das transações pix por trimestre:  2490206540416.67

# %% [markdown]
# Qual é a média por trasanção Pix?

# %%
soma_valores = df['valorPix'].sum() * 1e6
soma_valores
# Out:
# np.float64(59764956970000.0)

# %%
total_trasação = df['quantidadePix'].sum() * 1e3
total_trasação
# Out:
# np.float64(138758180090.0)

# %%
print("Média por transação Pix: ", round((soma_valores / total_trasação), 2))
# Out:
# Média por transação Pix:  430.71

# %% [markdown]
# Resolvendo com Pandas

# %%
df ['valorPix'].mean() * 1e6
# Out:
# np.float64(2490206540416.667)

# %% [markdown]
# O correto:

# %%
soma1 = df['valorPix'].mean() * 1e3
soma2 = df['quantidadePix'].mean()

soma1 / soma2
# Out:
# np.float64(430.71303566561505)

# %% [markdown]
# Testes:

# %%
(df['valorPix'] / df ['quantidadePix']).mean() * 1e3
# Out:
# np.float64(491.13828791552487)

# %%
df['valorPix'] / df['quantidadePix'].mean() * 1e3
# Out:
# 0     1334.254808
# 1     1206.489644
# 2     1086.949289
# 3      939.067738
# 4      916.729521
# 5      773.062241
# 6      674.620107
# 7      596.236983
# 8      578.199674
# 9      507.890308
# 10     439.910826
# 11     357.657020
# 12     331.469095
# 13     269.288551
# 14     191.251030
# 15     108.109781
# 16      25.926240
# 17       0.000000
# 18       0.000000
# 19       0.000000
# 20       0.000000
# 21       0.000000
# 22       0.000000
# 23       0.000000
# Name: valorPix, dtype: float64
